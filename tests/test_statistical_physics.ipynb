# %%
##!/usr/bin/env python3
# ## test_statistical_physics.py

# %%
"""
Information about jupytext
==========================
sudo pip3 install jupytext
Convert from .py to .ipynb format
In a notebook, do the following in a cell:
# !jupytext --to notebook <name_of_script_file>.py

test_statistical_physics.py connected to test_statistical_physics.ipynb via "jupytext".
In ipynb notebook select File->Jupytext->Pair Notebook with Light Format.

"""
# Out:
# '\nInformation about jupytext\n==========================\nsudo pip3 install jupytext\nConvert from .py to .ipynb format\nIn a notebook, do the following in a cell:\n!jupytext --to notebook <name_of_script_file>.py\n\ntest_statistical_physics.py connected to test_statistical_physics.ipynb via "jupytext".\nIn ipynb notebook select File->Jupytext->Pair Notebook with Light Format.\n\n'

# %%
import copy
import sys
import os
lstPaths = ["../src"]
for ipath in lstPaths:
    if ipath not in sys.path:
        sys.path.append(ipath)
from libsympy import *
from statistical_physics import *
# print(sys.version)
# print(sys.path)
# Execute jupyter-notebook related commands.
#exec(open('libnotebook.py').read())

# %% [markdown]
# ### Settings

# %%
### Settings
class sets:
    """
    Setttings class.
        
    Instead of settings class, settings nametuple might be used.
    Settings = namedtuple("Settings", "type dropinf delta")
    sets = Settings(type="symbolic", dropinf=True, delta=0.1)
    print(set.type)
    """
    global dictflow, test_all
    
    def __init__(self):
        pass
    
    # File settings
    input_dir  = "input/statistical_physics"
    output_dir = "output/statistical_physics"
    
    # Plotting settings
    plot_time_scale = {1:"xy", 2:"xz", 3:"yz"}[3]
    
    # Execution settings.
    test_all = {0:False, 1:True}[1]
    dictflow = dict(
        ch1 = {100:"get_formulary", 
                310:"1D_1/2_paramagnet_way1", 311:"1D_1/2_paramagnet_way2", 
                331:"1D_simple_harmonic_oscillator", 332:"",
                430:"monoatomic_ideal_gas",
                710:"ideal_gas_canonical"})
    flow = [dictflow["ch1"][i] for i in [311]]
    #if test_all: flow = [dictflow[i] for i in dictflow.keys()]
    if test_all: flow = flatten([list(dictflow[i].values()) for i in dictflow.keys()])

# %%
print("Test of the {0}.".format(sets.flow))
# Out:
# Test of the ['get_formulary', '1D_1/2_paramagnet_way1', '1D_1/2_paramagnet_way2', '1D_simple_harmonic_oscillator', '', 'monoatomic_ideal_gas', 'ideal_gas_canonical'].

# %% [markdown]
# ### get_formulary

# %%
### get_formulary
if "get_formulary" in sets.flow:
    ostat.__init__(class_type = "micro_canonical_discrete_distinguihable")
    ostat.get_formulary()
    
    ostat.__init__(class_type = "micro_canonical_discrete_indistinguihable")
    ostat.get_formulary()
    
    ostat.__init__(class_type = "micro_canonical_continuous_indistinguihable")
    ostat.get_formulary()
# Out:
# 'classname'
# 'statistical_mechanics'
# 'codes'
# []
# 'newline'
# True
# 'verbose'
# False
# 'output_style'
# 'display'
# 'result'
# None
# 'reflection_type'
# 'class'
# 'class_type'
# 'micro_canonical_discrete_distinguihable'
# 'numeric'
# False
# 'input_dir'
# 'input/statistical_physics'
# 'output_dir'
# 'output/statistical_physics'
# 'Z_Ideal_Gas'
#                 3⋅N
#                 ───
#                  2
#  N ⎛2⋅π⋅T⋅k_B⋅m⎞
# V ⋅⎜───────────⎟
#    ⎜     2     ⎟
#    ⎝    h      ⎠
# ───────────────────
#         N!
# 'Z_Ideal_Gas_beta'
#                 3⋅N
#                 ───
#                  2
#  N  -3⋅N ⎛2⋅π⋅m⎞
# V ⋅h    ⋅⎜─────⎟
#          ⎝  β  ⎠
# ───────────────────
#         N!
# 'Zsp'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
# 'ZN'
#                                    N
#       ⎛ n                         ⎞
#       ⎜____                       ⎟
#       ⎜╲                          ⎟
#       ⎜ ╲          -varepsilon(i) ⎟
#       ⎜  ╲         ───────────────⎟
# Z_N = ⎜  ╱              T⋅k_B     ⎟
#       ⎜ ╱    g(i)⋅ℯ               ⎟
#       ⎜╱                          ⎟
#       ⎜‾‾‾‾                       ⎟
#       ⎝i = j                      ⎠
# 'U'
#                ⎛   ⎛ n                         ⎞⎞
#                ⎜   ⎜____                       ⎟⎟
#                ⎜   ⎜╲                          ⎟⎟
#                ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟
#        2     ∂ ⎜   ⎜  ╲         ───────────────⎟⎟
# U = N⋅T ⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟
#              ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#                ⎜   ⎜╱                          ⎟⎟
#                ⎜   ⎜‾‾‾‾                       ⎟⎟
#                ⎝   ⎝i = j                      ⎠⎠
# 'S'
#               ⎛   ⎛ n                         ⎞⎞            ⎛ n                ↪
#               ⎜   ⎜____                       ⎟⎟            ⎜____              ↪
#               ⎜   ⎜╲                          ⎟⎟            ⎜╲                 ↪
#               ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟            ⎜ ╲          -vare ↪
#             ∂ ⎜   ⎜  ╲         ───────────────⎟⎟            ⎜  ╲         ───── ↪
# S = N⋅T⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟ + N⋅k_B⋅log⎜  ╱               ↪
#             ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟            ⎜ ╱    g(i)⋅ℯ      ↪
#               ⎜   ⎜╱                          ⎟⎟            ⎜╱                 ↪
#               ⎜   ⎜‾‾‾‾                       ⎟⎟            ⎜‾‾‾‾              ↪
#               ⎝   ⎝i = j                      ⎠⎠            ⎝i = j             ↪
#
# ↪           ⎞
# ↪           ⎟
# ↪           ⎟
# ↪ psilon(i) ⎟
# ↪ ──────────⎟
# ↪ T⋅k_B     ⎟
# ↪           ⎟
# ↪           ⎟
# ↪           ⎟
# ↪           ⎠
# 'F'
#                 ⎛ n                         ⎞
#                 ⎜____                       ⎟
#                 ⎜╲                          ⎟
#                 ⎜ ╲          -varepsilon(i) ⎟
#                 ⎜  ╲         ───────────────⎟
# F = -N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟
#                 ⎜ ╱    g(i)⋅ℯ               ⎟
#                 ⎜╱                          ⎟
#                 ⎜‾‾‾‾                       ⎟
#                 ⎝i = j                      ⎠
# 'Cv'
#        ⎛           ⎛   ⎛ n                         ⎞⎞⎞
#        ⎜           ⎜   ⎜____                       ⎟⎟⎟
#        ⎜           ⎜   ⎜╲                          ⎟⎟⎟
#        ⎜           ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟⎟
#      ∂ ⎜   2     ∂ ⎜   ⎜  ╲         ───────────────⎟⎟⎟
# Cᵥ = ──⎜N⋅T ⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟⎟
#      ∂T⎜         ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟⎟
#        ⎜           ⎜   ⎜╱                          ⎟⎟⎟
#        ⎜           ⎜   ⎜‾‾‾‾                       ⎟⎟⎟
#        ⎝           ⎝   ⎝i = j                      ⎠⎠⎠
# 'partition_function_sp'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
# 'partition_function_Np'
#                                    N
#       ⎛ n                         ⎞
#       ⎜____                       ⎟
#       ⎜╲                          ⎟
#       ⎜ ╲          -varepsilon(i) ⎟
#       ⎜  ╲         ───────────────⎟
# Z_N = ⎜  ╱              T⋅k_B     ⎟
#       ⎜ ╱    g(i)⋅ℯ               ⎟
#       ⎜╱                          ⎟
#       ⎜‾‾‾‾                       ⎟
#       ⎝i = j                      ⎠
# 'M'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠
# 'magnetization'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠
# 'classname'
# 'statistical_mechanics'
# 'codes'
# []
# 'newline'
# True
# 'verbose'
# False
# 'output_style'
# 'display'
# 'result'
# None
# 'reflection_type'
# 'class'
# 'class_type'
# 'micro_canonical_discrete_indistinguihable'
# 'numeric'
# False
# 'input_dir'
# 'input/statistical_physics'
# 'output_dir'
# 'output/statistical_physics'
# 'Z_Ideal_Gas'
#                 3⋅N
#                 ───
#                  2
#  N ⎛2⋅π⋅T⋅k_B⋅m⎞
# V ⋅⎜───────────⎟
#    ⎜     2     ⎟
#    ⎝    h      ⎠
# ───────────────────
#         N!
# 'Z_Ideal_Gas_beta'
#                 3⋅N
#                 ───
#                  2
#  N  -3⋅N ⎛2⋅π⋅m⎞
# V ⋅h    ⋅⎜─────⎟
#          ⎝  β  ⎠
# ───────────────────
#         N!
# 'Zsp'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
# 'ZN'
#                                    N
#       ⎛ n                         ⎞
#       ⎜____                       ⎟
#       ⎜╲                          ⎟
#       ⎜ ╲          -varepsilon(i) ⎟
#       ⎜  ╲         ───────────────⎟
#       ⎜  ╱              T⋅k_B     ⎟
#       ⎜ ╱    g(i)⋅ℯ               ⎟
#       ⎜╱                          ⎟
#       ⎜‾‾‾‾                       ⎟
#       ⎝i = j                      ⎠
# Z_N = ──────────────────────────────
#                     N!
# 'U'
#                ⎛   ⎛ n                         ⎞⎞
#                ⎜   ⎜____                       ⎟⎟
#                ⎜   ⎜╲                          ⎟⎟
#                ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟
#        2     ∂ ⎜   ⎜  ╲         ───────────────⎟⎟
# U = N⋅T ⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟
#              ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#                ⎜   ⎜╱                          ⎟⎟
#                ⎜   ⎜‾‾‾‾                       ⎟⎟
#                ⎝   ⎝i = j                      ⎠⎠
# 'S'
#               ⎛   ⎛ n                         ⎞⎞            ⎛ n                ↪
#               ⎜   ⎜____                       ⎟⎟            ⎜____              ↪
#               ⎜   ⎜╲                          ⎟⎟            ⎜╲                 ↪
#               ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟            ⎜ ╲          -vare ↪
#             ∂ ⎜   ⎜  ╲         ───────────────⎟⎟            ⎜  ╲         ───── ↪
# S = N⋅T⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟ + N⋅k_B⋅log⎜  ╱               ↪
#             ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟            ⎜ ╱    g(i)⋅ℯ      ↪
#               ⎜   ⎜╱                          ⎟⎟            ⎜╱                 ↪
#               ⎜   ⎜‾‾‾‾                       ⎟⎟            ⎜‾‾‾‾              ↪
#               ⎝   ⎝i = j                      ⎠⎠            ⎝i = j             ↪
#
# ↪           ⎞
# ↪           ⎟
# ↪           ⎟
# ↪ psilon(i) ⎟
# ↪ ──────────⎟
# ↪ T⋅k_B     ⎟ - k_B⋅log(N!)
# ↪           ⎟
# ↪           ⎟
# ↪           ⎟
# ↪           ⎠
# 'F'
#                  ⎛ n                         ⎞
#                  ⎜____                       ⎟
#                  ⎜╲                          ⎟
#                  ⎜ ╲          -varepsilon(i) ⎟
#                  ⎜  ╲         ───────────────⎟
# F = - N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟ + T⋅k_B⋅log(N!)
#                  ⎜ ╱    g(i)⋅ℯ               ⎟
#                  ⎜╱                          ⎟
#                  ⎜‾‾‾‾                       ⎟
#                  ⎝i = j                      ⎠
# 'Cv'
#        ⎛           ⎛   ⎛ n                         ⎞⎞⎞
#        ⎜           ⎜   ⎜____                       ⎟⎟⎟
#        ⎜           ⎜   ⎜╲                          ⎟⎟⎟
#        ⎜           ⎜   ⎜ ╲          -varepsilon(i) ⎟⎟⎟
#      ∂ ⎜   2     ∂ ⎜   ⎜  ╲         ───────────────⎟⎟⎟
# Cᵥ = ──⎜N⋅T ⋅k_B⋅──⎜log⎜  ╱              T⋅k_B     ⎟⎟⎟
#      ∂T⎜         ∂T⎜   ⎜ ╱    g(i)⋅ℯ               ⎟⎟⎟
#        ⎜           ⎜   ⎜╱                          ⎟⎟⎟
#        ⎜           ⎜   ⎜‾‾‾‾                       ⎟⎟⎟
#        ⎝           ⎝   ⎝i = j                      ⎠⎠⎠
# 'partition_function_sp'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
# 'partition_function_Np'
#                                    N
#       ⎛ n                         ⎞
#       ⎜____                       ⎟
#       ⎜╲                          ⎟
#       ⎜ ╲          -varepsilon(i) ⎟
#       ⎜  ╲         ───────────────⎟
#       ⎜  ╱              T⋅k_B     ⎟
#       ⎜ ╱    g(i)⋅ℯ               ⎟
#       ⎜╱                          ⎟
#       ⎜‾‾‾‾                       ⎟
#       ⎝i = j                      ⎠
# Z_N = ──────────────────────────────
#                     N!
# 'M'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠
# 'magnetization'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠
# 'classname'
# 'statistical_mechanics'
# 'codes'
# []
# 'newline'
# True
# 'verbose'
# False
# 'output_style'
# 'display'
# 'result'
# None
# 'reflection_type'
# 'class'
# 'class_type'
# 'micro_canonical_continuous_indistinguihable'
# 'numeric'
# False
# 'input_dir'
# 'input/statistical_physics'
# 'output_dir'
# 'output/statistical_physics'
# 'Z_Ideal_Gas'
#                 3⋅N
#                 ───
#                  2
#  N ⎛2⋅π⋅T⋅k_B⋅m⎞
# V ⋅⎜───────────⎟
#    ⎜     2     ⎟
#    ⎝    h      ⎠
# ───────────────────
#         N!
# 'Z_Ideal_Gas_beta'
#                 3⋅N
#                 ───
#                  2
#  N  -3⋅N ⎛2⋅π⋅m⎞
# V ⋅h    ⋅⎜─────⎟
#          ⎝  β  ⎠
# ───────────────────
#         N!
# 'Zsp'
#       ∞
#       ⌠
#       ⎮       -varepsilon(i)
#       ⎮       ───────────────
#       ⎮            T⋅k_B
# Zₛₚ = ⎮ g(i)⋅ℯ                d(varepsilon)
#       ⌡
#       0
# 'ZN'
#                                              N
#       ⎛∞                                    ⎞
#       ⎜⌠                                    ⎟
#       ⎜⎮       -varepsilon(i)               ⎟
#       ⎜⎮       ───────────────              ⎟
#       ⎜⎮            T⋅k_B                   ⎟
#       ⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟
#       ⎜⌡                                    ⎟
#       ⎝0                                    ⎠
# Z_N = ────────────────────────────────────────
#                          N!
# 'U'
#                ⎛   ⎛∞                                    ⎞⎞
#                ⎜   ⎜⌠                                    ⎟⎟
#                ⎜   ⎜⎮       -varepsilon(i)               ⎟⎟
#                ⎜   ⎜⎮       ───────────────              ⎟⎟
#        2     ∂ ⎜   ⎜⎮            T⋅k_B                   ⎟⎟
# U = N⋅T ⋅k_B⋅──⎜log⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟⎟
#              ∂T⎜   ⎜⌡                                    ⎟⎟
#                ⎝   ⎝0                                    ⎠⎠
# 'S'
#               ⎛   ⎛∞                                    ⎞⎞            ⎛∞       ↪
#               ⎜   ⎜⌠                                    ⎟⎟            ⎜⌠       ↪
#               ⎜   ⎜⎮       -varepsilon(i)               ⎟⎟            ⎜⎮       ↪
#               ⎜   ⎜⎮       ───────────────              ⎟⎟            ⎜⎮       ↪
#             ∂ ⎜   ⎜⎮            T⋅k_B                   ⎟⎟            ⎜⎮       ↪
# S = N⋅T⋅k_B⋅──⎜log⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟⎟ + N⋅k_B⋅log⎜⎮ g(i)⋅ ↪
#             ∂T⎜   ⎜⌡                                    ⎟⎟            ⎜⌡       ↪
#               ⎝   ⎝0                                    ⎠⎠            ⎝0       ↪
#
# ↪                               ⎞
# ↪                               ⎟
# ↪  -varepsilon(i)               ⎟
# ↪  ───────────────              ⎟
# ↪       T⋅k_B                   ⎟
# ↪ ℯ                d(varepsilon)⎟ - k_B⋅log(N!)
# ↪                               ⎟
# ↪                               ⎠
# 'F'
#                  ⎛∞                                    ⎞
#                  ⎜⌠                                    ⎟
#                  ⎜⎮       -varepsilon(i)               ⎟
#                  ⎜⎮       ───────────────              ⎟
#                  ⎜⎮            T⋅k_B                   ⎟
# F = - N⋅T⋅k_B⋅log⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟ + T⋅k_B⋅log(N!)
#                  ⎜⌡                                    ⎟
#                  ⎝0                                    ⎠
# 'Cv'
#        ⎛           ⎛   ⎛∞                                    ⎞⎞⎞
#        ⎜           ⎜   ⎜⌠                                    ⎟⎟⎟
#        ⎜           ⎜   ⎜⎮       -varepsilon(i)               ⎟⎟⎟
#        ⎜           ⎜   ⎜⎮       ───────────────              ⎟⎟⎟
#      ∂ ⎜   2     ∂ ⎜   ⎜⎮            T⋅k_B                   ⎟⎟⎟
# Cᵥ = ──⎜N⋅T ⋅k_B⋅──⎜log⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟⎟⎟
#      ∂T⎜         ∂T⎜   ⎜⌡                                    ⎟⎟⎟
#        ⎝           ⎝   ⎝0                                    ⎠⎠⎠
# 'partition_function_sp'
#       ∞
#       ⌠
#       ⎮       -varepsilon(i)
#       ⎮       ───────────────
#       ⎮            T⋅k_B
# Zₛₚ = ⎮ g(i)⋅ℯ                d(varepsilon)
#       ⌡
#       0
# 'partition_function_Np'
#                                              N
#       ⎛∞                                    ⎞
#       ⎜⌠                                    ⎟
#       ⎜⎮       -varepsilon(i)               ⎟
#       ⎜⎮       ───────────────              ⎟
#       ⎜⎮            T⋅k_B                   ⎟
#       ⎜⎮ g(i)⋅ℯ                d(varepsilon)⎟
#       ⎜⌡                                    ⎟
#       ⎝0                                    ⎠
# Z_N = ────────────────────────────────────────
#                          N!
# 'M'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠
# 'magnetization'
#        ⎛            ⎛ n                         ⎞⎞
#        ⎜            ⎜____                       ⎟⎟
#        ⎜            ⎜╲                          ⎟⎟
#        ⎜            ⎜ ╲          -varepsilon(i) ⎟⎟
#      ∂ ⎜            ⎜  ╲         ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱              T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    g(i)⋅ℯ               ⎟⎟
#        ⎜            ⎜╱                          ⎟⎟
#        ⎜            ⎜‾‾‾‾                       ⎟⎟
#        ⎝            ⎝i = j                      ⎠⎠

# %% [markdown]
# ## Chapter 3 Paramagnets and Oscillators

# %% [markdown]
# ### A Spin-1/2 Paramagnet Way1

# %%
#----A Spin-1/2 Paramagnet Way1
if "1D_1/2_paramagnet_way1" in sets.flow:
    print("A Spin-1/2 Paramagnet Way1")
    
    ostat.__init__(class_type = "micro_canonical_discrete_distinguihable")
    ostat.verbose = True
    [mu,B] = symbols('mu B', real=True)
    xreplaces = {g:1, engF:mu*B*(2*i-3), j:1, n:2}
    display("Single particle partition function:", ostat.Zsp)
    """
    res = ostat.Zsp.xreplace(xreplaces)
    display(simplify(res.doit()))
    """
    commands = ["xreplace", "ostat.Zsp", xreplaces]
    ostat.process(commands)
    Zsp = simplify(ostat.result.doit())
    display(Zsp)
    
    commands = ["xreplace", "ostat.U", xreplaces]
    ostat.process(commands)
    U = simplify(ostat.result.doit())
    display(U)
    
    commands = ["xreplace", "ostat.Cv", xreplaces]
    ostat.process(commands)
    Cv = simplify(ostat.result.doit())
    display(Cv)
    
    commands = ["xreplace", "ostat.S", xreplaces]
    ostat.process(commands)
    S = simplify(ostat.result.doit())
    display(S)
    
    commands = ["xreplace", "ostat.F", xreplaces]
    ostat.process(commands)
    F = simplify(ostat.result.doit())
    display(F)
    
    commands = ["xreplace", "ostat.M", xreplaces]
    ostat.process(commands)
    M = simplify(ostat.result.doit())
    display(M)
    
    simplify(ostat.M.evalf(subs=xreplaces).doit())
    
    # limM = limit(limit(M.rhs, T, 0), B, 0)
# Out:
# A Spin-1/2 Paramagnet Way1
# 'Single particle partition function:'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
# 'xreplace ostat.Zsp {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(Z_sp, Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n)))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#        2
#       ____
#       ╲
#        ╲     -B⋅μ⋅(2⋅i - 3)
#         ╲    ───────────────
# Zₛₚ =   ╱         T⋅k_B
#        ╱    ℯ
#       ╱
#       ‾‾‾‾
#       i = 1
#             ⎛ B⋅μ ⎞
# Zₛₚ = 2⋅cosh⎜─────⎟
#             ⎝T⋅k_B⎠
# 'xreplace ostat.U {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(U, N*T**2*k_B*Derivative(log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))), T))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#                ⎛   ⎛ 2                    ⎞⎞
#                ⎜   ⎜____                  ⎟⎟
#                ⎜   ⎜╲                     ⎟⎟
#                ⎜   ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟⎟
#        2     ∂ ⎜   ⎜  ╲    ───────────────⎟⎟
# U = N⋅T ⋅k_B⋅──⎜log⎜  ╱         T⋅k_B     ⎟⎟
#              ∂T⎜   ⎜ ╱    ℯ               ⎟⎟
#                ⎜   ⎜╱                     ⎟⎟
#                ⎜   ⎜‾‾‾‾                  ⎟⎟
#                ⎝   ⎝i = 1                 ⎠⎠
#                ⎛ B⋅μ ⎞
# U = -B⋅N⋅μ⋅tanh⎜─────⎟
#                ⎝T⋅k_B⎠
# 'xreplace ostat.Cv {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(C_v, Derivative(N*T**2*k_B*Derivative(log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))), T), T))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#        ⎛           ⎛   ⎛ 2                    ⎞⎞⎞
#        ⎜           ⎜   ⎜____                  ⎟⎟⎟
#        ⎜           ⎜   ⎜╲                     ⎟⎟⎟
#        ⎜           ⎜   ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟⎟⎟
#      ∂ ⎜   2     ∂ ⎜   ⎜  ╲    ───────────────⎟⎟⎟
# Cᵥ = ──⎜N⋅T ⋅k_B⋅──⎜log⎜  ╱         T⋅k_B     ⎟⎟⎟
#      ∂T⎜         ∂T⎜   ⎜ ╱    ℯ               ⎟⎟⎟
#        ⎜           ⎜   ⎜╱                     ⎟⎟⎟
#        ⎜           ⎜   ⎜‾‾‾‾                  ⎟⎟⎟
#        ⎝           ⎝   ⎝i = 1                 ⎠⎠⎠
#                        2⋅B⋅μ
#                        ─────
#                2    2  T⋅k_B
#             4⋅B ⋅N⋅μ ⋅ℯ
# Cᵥ = ──────────────────────────────
#             ⎛ 4⋅B⋅μ      2⋅B⋅μ    ⎞
#             ⎜ ─────      ─────    ⎟
#       2     ⎜ T⋅k_B      T⋅k_B    ⎟
#      T ⋅k_B⋅⎝ℯ      + 2⋅ℯ      + 1⎠
# 'xreplace ostat.S {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(S, N*T*k_B*Derivative(log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))), T) + N*k_B*log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#               ⎛   ⎛ 2                    ⎞⎞            ⎛ 2                    ⎞
#               ⎜   ⎜____                  ⎟⎟            ⎜____                  ⎟
#               ⎜   ⎜╲                     ⎟⎟            ⎜╲                     ⎟
#               ⎜   ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟⎟            ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟
#             ∂ ⎜   ⎜  ╲    ───────────────⎟⎟            ⎜  ╲    ───────────────⎟
# S = N⋅T⋅k_B⋅──⎜log⎜  ╱         T⋅k_B     ⎟⎟ + N⋅k_B⋅log⎜  ╱         T⋅k_B     ⎟
#             ∂T⎜   ⎜ ╱    ℯ               ⎟⎟            ⎜ ╱    ℯ               ⎟
#               ⎜   ⎜╱                     ⎟⎟            ⎜╱                     ⎟
#               ⎜   ⎜‾‾‾‾                  ⎟⎟            ⎜‾‾‾‾                  ⎟
#               ⎝   ⎝i = 1                 ⎠⎠            ⎝i = 1                 ⎠
#       ⎛                        ⎛                     ⎛ 2⋅B⋅μ    ⎞⎞⎞
#       ⎜                        ⎜                     ⎜ ─────    ⎟⎟⎟
#       ⎜      ⎛ 2⋅B⋅μ    ⎞      ⎜                     ⎜ T⋅k_B    ⎟⎟⎟
#       ⎜      ⎜ ─────    ⎟      ⎜               T⋅k_B⋅⎝ℯ      + 1⎠⎟⎟
#       ⎜      ⎜ T⋅k_B    ⎟      ⎜⎛      ⎛ B⋅μ ⎞⎞                  ⎟⎟
#     N⋅⎜- B⋅μ⋅⎝ℯ      - 1⎠ + log⎜⎜2⋅cosh⎜─────⎟⎟                  ⎟⎟
#       ⎝                        ⎝⎝      ⎝T⋅k_B⎠⎠                  ⎠⎠
# S = ───────────────────────────────────────────────────────────────
#                               ⎛ 2⋅B⋅μ    ⎞
#                               ⎜ ─────    ⎟
#                               ⎜ T⋅k_B    ⎟
#                             T⋅⎝ℯ      + 1⎠
# 'xreplace ostat.F {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(F, -N*T*k_B*log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#                 ⎛ 2                    ⎞
#                 ⎜____                  ⎟
#                 ⎜╲                     ⎟
#                 ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟
#                 ⎜  ╲    ───────────────⎟
# F = -N⋅T⋅k_B⋅log⎜  ╱         T⋅k_B     ⎟
#                 ⎜ ╱    ℯ               ⎟
#                 ⎜╱                     ⎟
#                 ⎜‾‾‾‾                  ⎟
#                 ⎝i = 1                 ⎠
#         ⎛               N⋅T⋅k_B⎞
#         ⎜⎛      ⎛ B⋅μ ⎞⎞       ⎟
# F = -log⎜⎜2⋅cosh⎜─────⎟⎟       ⎟
#         ⎝⎝      ⎝T⋅k_B⎠⎠       ⎠
# 'xreplace ostat.M {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2}'
# Eq(M, -Derivative(-N*T*k_B*log(Sum(g(i)*exp(-varepsilon(i)/(T*k_B)), (i, j, n))), B))(xreplace, {g(i): 1, varepsilon(i): B*mu*(2*i - 3), j: 1, n: 2})
#        ⎛            ⎛ 2                    ⎞⎞
#        ⎜            ⎜____                  ⎟⎟
#        ⎜            ⎜╲                     ⎟⎟
#        ⎜            ⎜ ╲     -B⋅μ⋅(2⋅i - 3) ⎟⎟
#      ∂ ⎜            ⎜  ╲    ───────────────⎟⎟
# M = -──⎜-N⋅T⋅k_B⋅log⎜  ╱         T⋅k_B     ⎟⎟
#      ∂B⎜            ⎜ ╱    ℯ               ⎟⎟
#        ⎜            ⎜╱                     ⎟⎟
#        ⎜            ⎜‾‾‾‾                  ⎟⎟
#        ⎝            ⎝i = 1                 ⎠⎠
#             ⎛ B⋅μ ⎞
# M = N⋅μ⋅tanh⎜─────⎟
#             ⎝T⋅k_B⎠

# %% [markdown]
# ### A Spin-1/2 Paramagnet Way2

# %%
#----A Spin-1/2 Paramagnet Way2
if "1D_1/2_paramagnet_way2" in sets.flow:
    print("A Spin-1/2 Paramagnet Way2")
    ostat.__init__(class_type = "micro_canonical_discrete_distinguihable")
    ostat.verbose = True
    ostat.numeric = True
    [mu,B] = symbols('mu B', real=True)
    xreplaces = {g:1, engF:mu*B*(2*i-3), j:1, n:2}
    display("Single particle partition function:", ostat.Zsp)
    
    Zsp = simplify(ostat.Zsp.evalf(subs=xreplaces).doit())
    U   = simplify(  ostat.U.evalf(subs=xreplaces).doit())
    Cv  = simplify( ostat.Cv.evalf(subs=xreplaces).doit())
    S   = simplify(  ostat.S.evalf(subs=xreplaces).doit())
    F   = simplify(  ostat.F.evalf(subs=xreplaces).doit())
    M   = simplify(  ostat.M.evalf(subs=xreplaces).doit())

    # list(map(display, [Zsp,U,Cv,S,F,M]))
    display(Zsp,U,Cv,S,F,M)
# Out:
# A Spin-1/2 Paramagnet Way2
# 'Single particle partition function:'
#        n
#       ____
#       ╲
#        ╲          -varepsilon(i)
#         ╲         ───────────────
# Zₛₚ =   ╱              T⋅k_B
#        ╱    g(i)⋅ℯ
#       ╱
#       ‾‾‾‾
#       i = j
#             ⎛ B⋅μ ⎞
# Zₛₚ = 2⋅cosh⎜─────⎟
#             ⎝T⋅k_B⎠
#                ⎛ B⋅μ ⎞
# U = -B⋅N⋅μ⋅tanh⎜─────⎟
#                ⎝T⋅k_B⎠
#                        2⋅B⋅μ
#                        ─────
#                2    2  T⋅k_B
#             4⋅B ⋅N⋅μ ⋅ℯ
# Cᵥ = ──────────────────────────────
#             ⎛ 4⋅B⋅μ      2⋅B⋅μ    ⎞
#             ⎜ ─────      ─────    ⎟
#       2     ⎜ T⋅k_B      T⋅k_B    ⎟
#      T ⋅k_B⋅⎝ℯ      + 2⋅ℯ      + 1⎠
#       ⎛                        ⎛                     ⎛ 2⋅B⋅μ    ⎞⎞⎞
#       ⎜                        ⎜                     ⎜ ─────    ⎟⎟⎟
#       ⎜      ⎛ 2⋅B⋅μ    ⎞      ⎜                     ⎜ T⋅k_B    ⎟⎟⎟
#       ⎜      ⎜ ─────    ⎟      ⎜               T⋅k_B⋅⎝ℯ      + 1⎠⎟⎟
#       ⎜      ⎜ T⋅k_B    ⎟      ⎜⎛      ⎛ B⋅μ ⎞⎞                  ⎟⎟
#     N⋅⎜- B⋅μ⋅⎝ℯ      - 1⎠ + log⎜⎜2⋅cosh⎜─────⎟⎟                  ⎟⎟
#       ⎝                        ⎝⎝      ⎝T⋅k_B⎠⎠                  ⎠⎠
# S = ───────────────────────────────────────────────────────────────
#                               ⎛ 2⋅B⋅μ    ⎞
#                               ⎜ ─────    ⎟
#                               ⎜ T⋅k_B    ⎟
#                             T⋅⎝ℯ      + 1⎠
#         ⎛               N⋅T⋅k_B⎞
#         ⎜⎛      ⎛ B⋅μ ⎞⎞       ⎟
# F = -log⎜⎜2⋅cosh⎜─────⎟⎟       ⎟
#         ⎝⎝      ⎝T⋅k_B⎠⎠       ⎠
#             ⎛ B⋅μ ⎞
# M = N⋅μ⋅tanh⎜─────⎟
#             ⎝T⋅k_B⎠

# %% [markdown]
# ### An Array of 1-D Simple Harmonic Oscillators

# %%
#----An Array of 1-D Simple Harmonic Oscillators
if "1D_simple_harmonic_oscillator" in sets.flow:
    print("1D_simple_harmonic_oscillator")
    print("An Array of 1-D Simple Harmonic Oscillators")
    
    ostat.class_type = "micro_canonical_discrete_distinguihable"
    ostat.__init__()
    ostat.verbose = False
    [h,nu,theta] = symbols('h nu theta', real=True, positive=True)
    xreplaces = {g:1, engF:(i+S(1)/2)*h*nu, j:0, n:inf, (h*nu)/kB:theta}
    display("Single particle partition function:", ostat.Zsp)

    commands = ["xreplace", "ostat.Zsp", xreplaces]
    ostat.result = ostat.process(commands).rhs
    Zsp = simplify(ostat.result.doit())
    display(Zsp)
    
    commands = ["xreplace", "ostat.U", xreplaces]
    ostat.result = ostat.process(commands).rhs
    U = simplify(ostat.result.doit())
    display(U)
    
    commands = ["xreplace", "ostat.Cv", xreplaces]
    ostat.result = ostat.process(commands).rhs
    Cv = simplify(ostat.result.doit())
    display(Cv)
# Out:
# 1D_simple_harmonic_oscillator
# An Array of 1-D Simple Harmonic Oscillators
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 10
#       8 ostat.verbose = False
#       9 [h,nu,theta] = symbols('h nu theta', real=True, positive=True)
# ---> 10 xreplaces = {g:1, engF:(i+S(1)/2)*h*nu, j:0, n:inf, (h*nu)/kB:theta}
#      11 display("Single particle partition function:", ostat.Zsp)
#      13 commands = ["xreplace", "ostat.Zsp", xreplaces]
#
# TypeError: 'Equality' object is not callable

# %% [markdown]
# ### An Array of 3-D Simple Harmonic Oscillators todo

# %% [markdown]
# ## Chapter 4 Indistinguishable Particles and Monatomic Ideal Gases

# %% [markdown]
# ### Monoatomic Ideal Gas

# %%
#----Monoatomic Ideal Gas
if "monoatomic_ideal_gas" in sets.flow:    
    print("Monoatomic Ideal Gas")
    ostat.__init__(class_type = "micro_canonical_continuous_indistinguihable")
    ostat.verbose = False
    [h,nu,theta] = symbols('h nu theta', real=True, positive=True)
    xreplaces = {i:eng, g:4*m*pi*V*(2*m*eng)**(S(1)/2)/(h**3), engF:eng}
    display("Single particle partition function:", ostat.Zsp)

    commands = ["xreplace", "ostat.Zsp", xreplaces]
    ostat.result = ostat.process(commands).rhs
    Zsp = simplify(ostat.result.doit())
    display(Zsp)
    
    commands = ["xreplace", "ostat.U", xreplaces]
    ostat.result = ostat.process(commands).rhs
    U = simplify(ostat.result.doit())
    display(U)
    
    commands = ["xreplace", "ostat.S", xreplaces]
    ostat.process(commands)
    S = simplify(ostat.result.doit())
    display(S)

# %% [markdown]
# ## Chapter 7 Electrons in Metals

# %% [markdown]
# ### The Ideal Gas in the Canonical Ensemble

# %%
#----The Ideal Gas in the Canonical Ensemble
if "ideal_gas_canonical" in sets.flow:
    print("The Ideal Gas in the Canonical Ensemble")
    ostat.__init__(class_type = "canonical")
    ostat.verbose = True
    
    ostat.ZN  = Eq( ostat.ZN.lhs, ostat.subformulary.Z_Ideal_Gas)
    display(ostat.F)
